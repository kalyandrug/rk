# %% [markdown]
# <a href="https://colab.research.google.com/github/kalyandrug/rk/blob/main/mltst1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Resources

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error

#upload file
from google.colab import files

# Upload the file auto csv file
uploaded = files.upload()

# Get the filename
filename = list(uploaded.keys())[0]
print(f"Uploaded file: {filename}")

# -----------------------------------------------------
# 1. Load data
# -----------------------------------------------------
# Option A: use your own auto MPG CSV (uncomment and edit path)
df = pd.read_csv(filename, na_values='?', comment='\t', sep=',', skipinitialspace=True)
df = df[['horsepower', 'mpg']].dropna()
#df = df[['horsepower', 'mpg']]

#print(df)

# Option B: small sample dataset (used if you don't have a CSV handy)
# data = {
#     'horsepower': [65, 88, 100, 110, 130, 150, 165, 190, 215, 225, 95, 140],
#     'mpg':        [46, 34, 30, 27, 22, 18, 16, 14, 12, 11, 31, 20]
# }
# df = pd.DataFrame(data)
#print(df.head())

# # -----------------------------------------------------
# # 2. Split into features (X) and target (y)
# # -----------------------------------------------------
X = df[['horsepower']]   # features must be 2D
y = df['mpg']             # target is 1D

# # -----------------------------------------------------
# # 3. Split into train/test sets
# # -----------------------------------------------------
X_train, X_test, y_train, y_test = train_test_split(
     X, y, test_size=0.3, random_state=42
 )
print(f"X_train: {X_train.shape}")
print(f"X_test: {X_test.shape}")
print(f"y_train: {y_train.shape}")
print(f"y_test: {y_test.shape}")
# # -----------------------------------------------------
# # 4. Train the model (this is where "learning" happens)
# # -----------------------------------------------------
model = LinearRegression()
model.fit(X_train, y_train)

w = model.coef_[0]
b = model.intercept_

print("=" * 50)
print(f"Learned equation:  mpg = {w:.4f} * horsepower + {b:.4f}")
print("=" * 50)

# # -----------------------------------------------------
# # 5. Use the model to predict on new/unseen data
# # -----------------------------------------------------
# new_horsepower = 120
# predicted_mpg = model.predict(pd.DataFrame({'horsepower': [new_horsepower]}))[0]
# manual_check = w * new_horsepower + b

# print(f"\nPredict mpg for horsepower = {new_horsepower}:")
# print(f"  model.predict() -> {predicted_mpg:.2f}")
# print(f"  by hand (w*x+b) -> {manual_check:.2f}")

# # -----------------------------------------------------
# # 6. Check accuracy on the held-out test set
# # -----------------------------------------------------
# y_pred_test = model.predict(X_test)
# mae = mean_absolute_error(y_test, y_pred_test)
# print(f"\nMean Absolute Error on test set: {mae:.2f} mpg")

# %%
# # Creating lists
scores = [85, 92, 78, 95, 88]
# features = ['age', 'income', 'credit_score']
# mixed = [1, 'hello', 3.14, True] # Allowed but rare in ML
# # Indexing (zero-based!)
# print(scores[0]) # 85 (first element)
# print(scores[-1]) # 88 (last element)
# # print(scores[1:4]) # [92, 78, 95] (slicing)

# # Modifying lists © 2025 AI Pathfinder Hub — For Cohort Use Only
# scores.append(99) # Add to end
# scores.insert(0, 70) # Insert at index 0
# scores.remove(78) # Remove first occurrence of 78
# scores.pop() # Remove and return last item
# # Useful functions
# print(len(scores)) # Number of elements
# print(max(scores)) # Maximum value
# print(min(scores)) # Minimum value
# print(sum(scores)) # Sum of all values
# print(sorted(scores)) # Returns new sorted list
# List comprehension (very Python!)
# squared = [x**2 for x in scores]
# above_90 = [s for s in scores if s > 90]
# print(above_90) # All scores above 90
# Creating dictionaries
model_config = {
'name': 'RandomForest',
'n_estimators': 100,
'max_depth': 5,
'random_state': 42
}
# # Accessing values
# print(model_config['name']) # RandomForest
# print(model_config.get('learning_rate', 0.01)) # Default if key missing
# Adding / updating
model_config['n_jobs'] = -1 # Add new key
model_config['n_estimators'] = 200 # Update existing key
# Iterating
for key, value in model_config.items():
  print(f'{key}: {value}')

# Useful methods
print(model_config.keys()) # All keys
print(model_config.values()) # All values
print('name' in model_config) # True — membership test
