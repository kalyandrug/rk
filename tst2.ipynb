# %% [markdown]
# <a href="https://colab.research.google.com/github/kalyandrug/rk/blob/main/tst2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
age = 19

if age <= 18:
    print("you are not eligible to vote")
else:
    print("you are eligible to vote")

# %%
student_name = "priaya"
score = 87.5
passed = score >= 50
attempts = 3

print(type(score))
#f -string - the modern way to combine text + variable
print(f"{student_name} has a score of {score}")

# %%
accuracy = 0.75
if accuracy >= .9 :
  print("Excelent Model")
elif accuracy >= 0.7 :
  print ("Decent Model")
elif accuracy >= 0.5 :
  print ("Poor Model")
else :
  print ("Bad Model")

# %%
#for loop
# Models = ["LogREg", "KgBoost", "MLP"]

# for model in Models :
#   print(f"training {model}...")

#   # range() -- loop ntimes (used for epochs)
# for epoch in range(3) : #0,1,2
#   print(f" Epoch {epoch+1}/3 complete")

#while loop --repeat until condition changes
# loss = 1.0
# while loss > 0.1 :
#   loss -= 0.3
#   print(loss)
# print(loss)

#List -- ordered , changable

scores = [85, 92, 78, 95]

# #access by position
# print(scores[0]) # 85
# print(scores[-1]) # 95 last item

# #add / remove
#scores.append(88)
#scores.remove(78)
# scores.remove(scores[len(scores)-1])
# print(scores) #removed last value
#usefull built-ins
# print(len(scores)) #4
# print(max(scores)) #95
# print(min(scores)) #85
# print(sum(scores)/len(scores)) #average

# #slicing - very commin in ML
# print(scores[1:3]) #92. 88

# Tuple ordered , unchangeable
#parantheses instead of brackets
# image_shape = (224, 224, 3)
#common :  image, dimentions, coordiantions
# the most-used structures in. ML model -- Dictionaires
# model_config = {
#     "name": "XgBoost",
#     "max_depth": 6,
#     "learning_rate": 0.1,
#     "n_estimators": 200
# }
#print(model_config["learning_rate"]) # "XgBoost
# Access by key, not position
# print(model_config.get("gpu", false))

# #loop through dictionary
# for key,value in model_config.items():
#   print(f"{key}:{value}")

## Set -uniqye , unorderd values
##automatically removes duplicates
# labels = ["cat", "dog", "cat", "bird", "dog"]
# uniq_label = set(labels)

# print(uniq_label)

# print(len(uniq_label))

#functions - package logic once, use everywhere
#basic function syntax
def calcualte_accuracy(correct, total) :
#retrun accurency as a percentage
  accuracy = (correct / total) * 100
  return accuracy

#calling the function
result = calcualte_accuracy(87, 100)
#print(f"Accuracy: {result}%")

#default parameters values
# def train_model(data, epochs=10, verbose=True) :
#   if verbose :
#       print(f"Training for {epochs} epoches...")
#   train_model(my_data) #uses defaults
#   train_model(my_data, epochs=50)

  #lamda single line function
# square = lambda x: x ** 2
# #print(square(5)) #9

#   #common with sorting
# students = [("amit",72), ("riya",95), ("suma",81)]
# students.sort(key=lambda s: s[1], reverse=True)
# print(students)
#   #args -- accept any numbers of inputs
# def average(*numbers):
#     return (sum(numbers)/len(numbers))
#     print(average(4, 8, 15, 16))

#   #any accept any named settings
# def build_model(**settings):
#   print(settings)
#   build_model(layers=3, dropout=0.2)
#Transfer every value
# celsius = [0, 20, 37, 100]
# fahrenheit = [celsius * 9/5 + 32 for c in  celsius ]
# #clean text data
# reviews = ["Great", "Bad", "Okey"]
# cleaned = [r.lower().strip() for r in reviews]
# print(cleaned)

# #dict comprehensive - pair lables with IDs
# classes = ["cat", "dog", "bird"]
# label_map = {name: i for i, name in enumerate(classes)}
# print(label_map)

   #without error handling it will crashes
# result = 10 / 0
# #zero division error : division by zero
# #with error handling it recovers
# except ZeroDivisionError:
# print("Can not divide by zero")
# result = 0
# print(result)
# #Real ML example
# response = client.chat.completion.create(
#     model="gpt"
# )
#write to file
# with open("notes.txt", "w") as f:
#   f.write("Model trained successfully")

# #Read from a file
# with open("notes.txt", "r") as f:
#   content = f.read()
#   print(content)

import json
#python dict - jason string (for sending)
payload = {"model": "gpt-40", "temparature":0.7}
json_string = json.dumps(payload)
print(json_string)

#jason string - python dict (from API response)
response_txt = '{"answer: "42", "confidence":0.95}'
data = json.loads(response_txt)
print(data["answer"])
